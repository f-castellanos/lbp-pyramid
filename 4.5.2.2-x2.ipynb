# %%
import os
os.environ['J_NOTEBOOK'] = '1'


from preprocess.preprocess import *
import PARAMETERS

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path
from confusion_matrix_pretty_print import print_confusion_matrix

# %matplotlib inline

# %%
PARAMETERS.LBP_METHOD = 'default'
PARAMETERS.METHOD = 'get_pyramid_dataset'
PARAMETERS.INTERPOLATION_ALGORITHM = 'lanczos'
PARAMETERS.BALANCE = False
PARAMETERS.N_SCALES = 1
PARAMETERS.GRAY_INTENSITY = False
PARAMETERS.X2SCALE = True
PARAMETERS.CHANNEL = None
PARAMETERS.FILE_EXTENSION = PARAMETERS.update_file_extension(PARAMETERS)
PARAMETERS.PLOT = True
PARAMETERS.DATASET = 'DRIVE'

pd.DataFrame({k: getattr(PARAMETERS, k) for k in VALID_PARAMETERS.keys()}, index=['Parameters']).head()
# Out:
#            LBP_METHOD               METHOD INTERPOLATION_ALGORITHM  BALANCE  \
# Parameters    default  get_pyramid_dataset                 lanczos    False
#
#             N_SCALES  GRAY_INTENSITY  X2SCALE
# Parameters         1           False     True

# %% [markdown]
# ## Cálculo con radio 1 a diferentes escalas

# %%
from main import main

PARAMETERS.N_SCALES = 2
PARAMETERS.FILE_EXTENSION = PARAMETERS.update_file_extension(PARAMETERS)
main(lgb='Num', all_lbp=True, plot_once=True)
# Out:
# Columns: Index(['default_1:1', 'default_2:1_1', 'default_2:1_2', 'default_2:1_3',
#        'default_2:1_4', 'riu_1:1', 'riu_2:1_1', 'riu_2:1_2', 'riu_2:1_3',
#        'riu_2:1_4', 'riu2_1:1', 'riu2_2:1_1', 'riu2_2:1_2', 'riu2_2:1_3',
#        'riu2_2:1_4', 'nriuniform_1:1', 'nriuniform_2:1_1', 'nriuniform_2:1_2',
#        'nriuniform_2:1_3', 'nriuniform_2:1_4', 'var_1:1', 'var_2:1_1',
#        'var_2:1_2', 'var_2:1_3', 'var_2:1_4'],
#       dtype='object')
# Accuracy score: 0.8892359105809245
#
# F1 score: 0.47711360920097695
#
# Confusion matrix:
#
#      t/p      0     1
#         0 1142905 44640
#         1 106299 68863
# Sensivity: 0.39313892282572704
# Specificity: 0.9624098455216434
# (0.889, 0.477, 1142905, 44640, 106299, 68863)

# %%
PARAMETERS.N_SCALES = 3
PARAMETERS.FILE_EXTENSION = PARAMETERS.update_file_extension(PARAMETERS)
main(lgb='Num', all_lbp=True, plot_once=True)
# Out:
# Columns: Index(['default_1:1', 'default_1:2', 'default_2:1_1', 'default_2:1_2',
#        'default_2:1_3', 'default_2:1_4', 'riu_1:1', 'riu_1:2', 'riu_2:1_1',
#        'riu_2:1_2', 'riu_2:1_3', 'riu_2:1_4', 'riu2_1:1', 'riu2_1:2',
#        'riu2_2:1_1', 'riu2_2:1_2', 'riu2_2:1_3', 'riu2_2:1_4',
#        'nriuniform_1:1', 'nriuniform_1:2', 'nriuniform_2:1_1',
#        'nriuniform_2:1_2', 'nriuniform_2:1_3', 'nriuniform_2:1_4', 'var_1:1',
#        'var_1:2', 'var_2:1_1', 'var_2:1_2', 'var_2:1_3', 'var_2:1_4'],
#       dtype='object')
# Accuracy score: 0.9067715950677585
#
# F1 score: 0.5971096854396518
#
# Confusion matrix:
#
#      t/p      0     1
#         0 1141521 46024
#         1 81019 94143
# Sensivity: 0.5374624633196697
# Specificity: 0.9612444160010779
# (0.907, 0.597, 1141521, 46024, 81019, 94143)

# %%
PARAMETERS.N_SCALES = 4
PARAMETERS.FILE_EXTENSION = PARAMETERS.update_file_extension(PARAMETERS)
main(lgb='Num', all_lbp=True, plot_once=True)
# Out:
# Columns: Index(['default_1:1', 'default_1:2', 'default_1:4', 'default_2:1_1',
#        'default_2:1_2', 'default_2:1_3', 'default_2:1_4', 'riu_1:1', 'riu_1:2',
#        'riu_1:4', 'riu_2:1_1', 'riu_2:1_2', 'riu_2:1_3', 'riu_2:1_4',
#        'riu2_1:1', 'riu2_1:2', 'riu2_1:4', 'riu2_2:1_1', 'riu2_2:1_2',
#        'riu2_2:1_3', 'riu2_2:1_4', 'nriuniform_1:1', 'nriuniform_1:2',
#        'nriuniform_1:4', 'nriuniform_2:1_1', 'nriuniform_2:1_2',
#        'nriuniform_2:1_3', 'nriuniform_2:1_4', 'var_1:1', 'var_1:2', 'var_1:4',
#        'var_2:1_1', 'var_2:1_2', 'var_2:1_3', 'var_2:1_4'],
#       dtype='object')
# Accuracy score: 0.9193517021634144
#
# F1 score: 0.6592839692952541
#
# Confusion matrix:
#
#      t/p      0     1
#         0 1146479 41066
#         1 68834 106328
# Sensivity: 0.6070266381977826
# Specificity: 0.9654194156853003
# (0.919, 0.659, 1146479, 41066, 68834, 106328)

# %%
PARAMETERS.N_SCALES = 5
PARAMETERS.FILE_EXTENSION = PARAMETERS.update_file_extension(PARAMETERS)
main(lgb='Num', all_lbp=True, plot_once=True)
# Out:
# Columns: Index(['default_1:1', 'default_1:2', 'default_1:4', 'default_1:8',
#        'default_2:1_1', 'default_2:1_2', 'default_2:1_3', 'default_2:1_4',
#        'riu_1:1', 'riu_1:2', 'riu_1:4', 'riu_1:8', 'riu_2:1_1', 'riu_2:1_2',
#        'riu_2:1_3', 'riu_2:1_4', 'riu2_1:1', 'riu2_1:2', 'riu2_1:4',
#        'riu2_1:8', 'riu2_2:1_1', 'riu2_2:1_2', 'riu2_2:1_3', 'riu2_2:1_4',
#        'nriuniform_1:1', 'nriuniform_1:2', 'nriuniform_1:4', 'nriuniform_1:8',
#        'nriuniform_2:1_1', 'nriuniform_2:1_2', 'nriuniform_2:1_3',
#        'nriuniform_2:1_4', 'var_1:1', 'var_1:2', 'var_1:4', 'var_1:8',
#        'var_2:1_1', 'var_2:1_2', 'var_2:1_3', 'var_2:1_4'],
#       dtype='object')
# Accuracy score: 0.9219692861341433
#
# F1 score: 0.6766824474505977
#
# Confusion matrix:
#
#      t/p      0     1
#         0 1145100 42445
#         1 63888 111274
# Sensivity: 0.6352633562073966
# Specificity: 0.9642581965314999
# (0.922, 0.677, 1145100, 42445, 63888, 111274)

# %%
PARAMETERS.N_SCALES = 6
PARAMETERS.FILE_EXTENSION = PARAMETERS.update_file_extension(PARAMETERS)
main(lgb='Num', all_lbp=True, plot_once=True)
# Out:
# Columns: Index(['default_1:1', 'default_1:2', 'default_1:4', 'default_1:8',
#        'default_1:16', 'default_2:1_1', 'default_2:1_2', 'default_2:1_3',
#        'default_2:1_4', 'riu_1:1', 'riu_1:2', 'riu_1:4', 'riu_1:8', 'riu_1:16',
#        'riu_2:1_1', 'riu_2:1_2', 'riu_2:1_3', 'riu_2:1_4', 'riu2_1:1',
#        'riu2_1:2', 'riu2_1:4', 'riu2_1:8', 'riu2_1:16', 'riu2_2:1_1',
#        'riu2_2:1_2', 'riu2_2:1_3', 'riu2_2:1_4', 'nriuniform_1:1',
#        'nriuniform_1:2', 'nriuniform_1:4', 'nriuniform_1:8', 'nriuniform_1:16',
#        'nriuniform_2:1_1', 'nriuniform_2:1_2', 'nriuniform_2:1_3',
#        'nriuniform_2:1_4', 'var_1:1', 'var_1:2', 'var_1:4', 'var_1:8',
#        'var_1:16', 'var_2:1_1', 'var_2:1_2', 'var_2:1_3', 'var_2:1_4'],
#       dtype='object')
# Accuracy score: 0.9190743131135306
#
# F1 score: 0.6699310997108702
#
# Confusion matrix:
#
#      t/p      0     1
#         0 1140515 47030
#         1 63248 111914
# Sensivity: 0.6389171167262305
# Specificity: 0.9603972902079501
# (0.919, 0.67, 1140515, 47030, 63248, 111914)
