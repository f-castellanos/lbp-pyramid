# %%
import os
os.environ['J_NOTEBOOK'] = '1'


from preprocess.preprocess import *
import PARAMETERS

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path
from confusion_matrix_pretty_print import print_confusion_matrix

# %matplotlib inline

# %%
PARAMETERS.LBP_METHOD = 'default'
PARAMETERS.METHOD = 'get_pyramid_dataset'
PARAMETERS.INTERPOLATION_ALGORITHM = 'lanczos'
PARAMETERS.BALANCE = False
PARAMETERS.N_SCALES = 1
PARAMETERS.GRAY_INTENSITY = True
PARAMETERS.X2SCALE = False
PARAMETERS.CHANNEL = None
PARAMETERS.FILE_EXTENSION = PARAMETERS.update_file_extension(PARAMETERS)
PARAMETERS.PLOT = True
PARAMETERS.DATASET = 'DRIVE'

pd.DataFrame({k: getattr(PARAMETERS, k) for k in VALID_PARAMETERS.keys()}, index=['Parameters']).head()
# Out:
#            LBP_METHOD               METHOD INTERPOLATION_ALGORITHM  BALANCE  \
# Parameters    default  get_pyramid_dataset                 lanczos    False
#
#             N_SCALES  GRAY_INTENSITY  X2SCALE
# Parameters         1            True    False

# %% [markdown]
# ## Cálculo con radio 1 a diferentes escalas

# %%
from main import main

PARAMETERS.FILE_EXTENSION = PARAMETERS.update_file_extension(PARAMETERS)
main(lgb='Num', all_lbp=True, plot_once=True)
# Out:
# Columns: Index(['Original', 'default_1:1', 'riu_1:1', 'riu2_1:1', 'nriuniform_1:1',
#        'var_1:1'],
#       dtype='object')
# Accuracy score: 0.8984609310732241
#
# F1 score: 0.5697726481269589
#
# Confusion matrix:
#
#      t/p      0     1
#         0 1132715 54830
#         1 83538 91624
# Sensivity: 0.5230814902775717
# Specificity: 0.9538291180544737
# (0.898, 0.57, 1132715, 54830, 83538, 91624)

# %%
PARAMETERS.N_SCALES = 2
PARAMETERS.FILE_EXTENSION = PARAMETERS.update_file_extension(PARAMETERS)
main(lgb='Num', all_lbp=True, plot_once=True)
# Out:
# Columns: Index(['Original', 'default_1:1', 'default_1:2', 'riu_1:1', 'riu_1:2',
#        'riu2_1:1', 'riu2_1:2', 'nriuniform_1:1', 'nriuniform_1:2', 'var_1:1',
#        'var_1:2'],
#       dtype='object')
# Accuracy score: 0.9173461353027467
#
# F1 score: 0.6614811720259796
#
# Confusion matrix:
#
#      t/p      0     1
#         0 1140029 47516
#         1 65117 110045
# Sensivity: 0.6282469942110732
# Specificity: 0.9599880425583872
# (0.917, 0.661, 1140029, 47516, 65117, 110045)

# %%
PARAMETERS.N_SCALES = 3
PARAMETERS.FILE_EXTENSION = PARAMETERS.update_file_extension(PARAMETERS)
main(lgb='Num', all_lbp=True, plot_once=True)
# Out:
# Columns: Index(['Original', 'default_1:1', 'default_1:2', 'default_1:4', 'riu_1:1',
#        'riu_1:2', 'riu_1:4', 'riu2_1:1', 'riu2_1:2', 'riu2_1:4',
#        'nriuniform_1:1', 'nriuniform_1:2', 'nriuniform_1:4', 'var_1:1',
#        'var_1:2', 'var_1:4'],
#       dtype='object')
# Accuracy score: 0.9238853253120444
#
# F1 score: 0.6901045712578429
#
# Confusion matrix:
#
#      t/p      0     1
#         0 1143496 44049
#         1 59673 115489
# Sensivity: 0.6593267946244048
# Specificity: 0.9629075108732722
# (0.924, 0.69, 1143496, 44049, 59673, 115489)

# %%
PARAMETERS.N_SCALES = 4
PARAMETERS.FILE_EXTENSION = PARAMETERS.update_file_extension(PARAMETERS)
main(lgb='Num', all_lbp=True, plot_once=True)
# Out:
# Columns: Index(['Original', 'default_1:1', 'default_1:2', 'default_1:4', 'default_1:8',
#        'riu_1:1', 'riu_1:2', 'riu_1:4', 'riu_1:8', 'riu2_1:1', 'riu2_1:2',
#        'riu2_1:4', 'riu2_1:8', 'nriuniform_1:1', 'nriuniform_1:2',
#        'nriuniform_1:4', 'nriuniform_1:8', 'var_1:1', 'var_1:2', 'var_1:4',
#        'var_1:8'],
#       dtype='object')
# Accuracy score: 0.924520825092995
#
# F1 score: 0.6980985870018257
#
# Confusion matrix:
#
#      t/p      0     1
#         0 1140932 46613
#         1 56243 118919
# Sensivity: 0.6789086674050308
# Specificity: 0.9607484347961551
# (0.925, 0.698, 1140932, 46613, 56243, 118919)

# %%
PARAMETERS.N_SCALES = 5
PARAMETERS.FILE_EXTENSION = PARAMETERS.update_file_extension(PARAMETERS)
main(lgb='Num', all_lbp=True, plot_once=True)
# Out:
# Columns: Index(['Original', 'default_1:1', 'default_1:2', 'default_1:4', 'default_1:8',
#        'default_1:16', 'riu_1:1', 'riu_1:2', 'riu_1:4', 'riu_1:8', 'riu_1:16',
#        'riu2_1:1', 'riu2_1:2', 'riu2_1:4', 'riu2_1:8', 'riu2_1:16',
#        'nriuniform_1:1', 'nriuniform_1:2', 'nriuniform_1:4', 'nriuniform_1:8',
#        'nriuniform_1:16', 'var_1:1', 'var_1:2', 'var_1:4', 'var_1:8',
#        'var_1:16'],
#       dtype='object')
# Accuracy score: 0.9227148609348892
#
# F1 score: 0.6921338723774946
#
# Confusion matrix:
#
#      t/p      0     1
#         0 1139005 48540
#         1 56777 118385
# Sensivity: 0.6758600609721287
# Specificity: 0.9591257594449052
# (0.923, 0.692, 1139005, 48540, 56777, 118385)

# %%
PARAMETERS.N_SCALES = 6
PARAMETERS.FILE_EXTENSION = PARAMETERS.update_file_extension(PARAMETERS)
main(lgb='Num', all_lbp=True, plot_once=True)
# Out:
# Columns: Index(['Original', 'default_1:1', 'default_1:2', 'default_1:4', 'default_1:8',
#        'default_1:16', 'default_1:32', 'riu_1:1', 'riu_1:2', 'riu_1:4',
#        'riu_1:8', 'riu_1:16', 'riu_1:32', 'riu2_1:1', 'riu2_1:2', 'riu2_1:4',
#        'riu2_1:8', 'riu2_1:16', 'riu2_1:32', 'nriuniform_1:1',
#        'nriuniform_1:2', 'nriuniform_1:4', 'nriuniform_1:8', 'nriuniform_1:16',
#        'nriuniform_1:32', 'var_1:1', 'var_1:2', 'var_1:4', 'var_1:8',
#        'var_1:16', 'var_1:32'],
#       dtype='object')
# Accuracy score: 0.9205544552130429
#
# F1 score: 0.6866260069644454
#
# Confusion matrix:
#
#      t/p      0     1
#         0 1135842 51703
#         1 56558 118604
# Sensivity: 0.6771103321496672
# Specificity: 0.9564622814293353
# (0.921, 0.687, 1135842, 51703, 56558, 118604)
