# %%
import os
os.environ['J_NOTEBOOK'] = '1'


from preprocess.preprocess import *
import PARAMETERS

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path
from confusion_matrix_pretty_print import print_confusion_matrix

# %matplotlib inline

# %%
PARAMETERS.LBP_METHOD = 'default'
PARAMETERS.METHOD = 'get_pyramid_dataset'
PARAMETERS.INTERPOLATION_ALGORITHM = 'lanczos'
PARAMETERS.BALANCE = False
PARAMETERS.N_SCALES = 6
PARAMETERS.GRAY_INTENSITY = False
PARAMETERS.X2SCALE = False
PARAMETERS.CHANNEL = None
PARAMETERS.DATASET = 'DRIVE'
PARAMETERS.FILE_EXTENSION = PARAMETERS.update_file_extension(PARAMETERS)
PARAMETERS.PLOT = True

pd.DataFrame({k: getattr(PARAMETERS, k) for k in VALID_PARAMETERS.keys()}, index=['Parameters']).head()
# Out:
#            LBP_METHOD               METHOD INTERPOLATION_ALGORITHM  BALANCE  \
# Parameters    default  get_pyramid_dataset                 lanczos    False
#
#             N_SCALES  GRAY_INTENSITY  X2SCALE
# Parameters         6           False    False

# %% [markdown]
# ## Cálculo con múltiples radios

# %%
from main import main

PARAMETERS.N_SCALES = 1
PARAMETERS.X2SCALE = False
PARAMETERS.FILE_EXTENSION = PARAMETERS.update_file_extension(PARAMETERS)
main(lgb='Num', all_lbp=True, plot_once=True, validation=False)
# Out:
# Columns: Index(['default_1:1', 'riu_1:1', 'riu2_1:1', 'nriuniform_1:1', 'var_1:1'], dtype='object')
# Accuracy score: 0.8783039934483349
#
# F1 score: 0.39296015930421546
#
# Confusion matrix:
#
#      t/p      0     1
#         0 1143195 44350
#         1 121486 53676
# Sensivity: 0.3064363275139585
# Specificity: 0.9626540467940162
# (0.878, 0.393, 1143195, 44350, 121486, 53676)

# %%
PARAMETERS.N_SCALES = 2
PARAMETERS.FILE_EXTENSION = PARAMETERS.update_file_extension(PARAMETERS)
main(lgb='Num', all_lbp=True, plot_once=True)
# Out:
# Columns: Index(['default_1:1', 'default_1:2', 'riu_1:1', 'riu_1:2', 'riu2_1:1',
#        'riu2_1:2', 'nriuniform_1:1', 'nriuniform_1:2', 'var_1:1', 'var_1:2'],
#       dtype='object')
# Accuracy score: 0.9006257397958622
#
# F1 score: 0.5614219182163839
#
# Confusion matrix:
#
#      t/p      0     1
#         0 1140615 46930
#         1 88488 86674
# Sensivity: 0.49482193626471493
# Specificity: 0.960481497543251
# (0.901, 0.561, 1140615, 46930, 88488, 86674)

# %%
PARAMETERS.N_SCALES = 3
PARAMETERS.FILE_EXTENSION = PARAMETERS.update_file_extension(PARAMETERS)
main(lgb='Num', all_lbp=True, plot_once=True)
# Out:
# Columns: Index(['default_1:1', 'default_1:2', 'default_1:4', 'riu_1:1', 'riu_1:2',
#        'riu_1:4', 'riu2_1:1', 'riu2_1:2', 'riu2_1:4', 'nriuniform_1:1',
#        'nriuniform_1:2', 'nriuniform_1:4', 'var_1:1', 'var_1:2', 'var_1:4'],
#       dtype='object')
# Accuracy score: 0.9142324799094743
#
# F1 score: 0.6340534786148162
#
# Confusion matrix:
#
#      t/p      0     1
#         0 1144579 42966
#         1 73910 101252
# Sensivity: 0.5780477500827805
# Specificity: 0.9638194763145818
# (0.914, 0.634, 1144579, 42966, 73910, 101252)

# %%
PARAMETERS.N_SCALES = 4
PARAMETERS.FILE_EXTENSION = PARAMETERS.update_file_extension(PARAMETERS)
main(lgb='Num', all_lbp=True, plot_once=True)
# Out:
# Columns: Index(['default_1:1', 'default_1:2', 'default_1:4', 'default_1:8', 'riu_1:1',
#        'riu_1:2', 'riu_1:4', 'riu_1:8', 'riu2_1:1', 'riu2_1:2', 'riu2_1:4',
#        'riu2_1:8', 'nriuniform_1:1', 'nriuniform_1:2', 'nriuniform_1:4',
#        'nriuniform_1:8', 'var_1:1', 'var_1:2', 'var_1:4', 'var_1:8'],
#       dtype='object')
# Accuracy score: 0.9159173615458055
#
# F1 score: 0.6519546793839799
#
# Confusion matrix:
#
#      t/p      0     1
#         0 1140812 46733
#         1 67847 107315
# Sensivity: 0.612661421997922
# Specificity: 0.960647385993794
# (0.916, 0.652, 1140812, 46733, 67847, 107315)

# %%
PARAMETERS.N_SCALES = 5
PARAMETERS.FILE_EXTENSION = PARAMETERS.update_file_extension(PARAMETERS)
main(lgb='Num', all_lbp=True, plot_once=True)
# Out:
# Columns: Index(['default_1:1', 'default_1:2', 'default_1:4', 'default_1:8',
#        'default_1:16', 'riu_1:1', 'riu_1:2', 'riu_1:4', 'riu_1:8', 'riu_1:16',
#        'riu2_1:1', 'riu2_1:2', 'riu2_1:4', 'riu2_1:8', 'riu2_1:16',
#        'nriuniform_1:1', 'nriuniform_1:2', 'nriuniform_1:4', 'nriuniform_1:8',
#        'nriuniform_1:16', 'var_1:1', 'var_1:2', 'var_1:4', 'var_1:8',
#        'var_1:16'],
#       dtype='object')
# Accuracy score: 0.9146448943169735
#
# F1 score: 0.6496608474596692
#
# Confusion matrix:
#
#      t/p      0     1
#         0 1138548 48997
#         1 67317 107845
# Sensivity: 0.6156871924275813
# Specificity: 0.9587409319225798
# (0.915, 0.65, 1138548, 48997, 67317, 107845)

# %%
PARAMETERS.N_SCALES = 6
PARAMETERS.FILE_EXTENSION = PARAMETERS.update_file_extension(PARAMETERS)
main(lgb='Num', all_lbp=True, plot_once=True)
# Out:
# Columns: Index(['default_1:1', 'default_1:2', 'default_1:4', 'default_1:8',
#        'default_1:16', 'default_1:32', 'riu_1:1', 'riu_1:2', 'riu_1:4',
#        'riu_1:8', 'riu_1:16', 'riu_1:32', 'riu2_1:1', 'riu2_1:2', 'riu2_1:4',
#        'riu2_1:8', 'riu2_1:16', 'riu2_1:32', 'nriuniform_1:1',
#        'nriuniform_1:2', 'nriuniform_1:4', 'nriuniform_1:8', 'nriuniform_1:16',
#        'nriuniform_1:32', 'var_1:1', 'var_1:2', 'var_1:4', 'var_1:8',
#        'var_1:16', 'var_1:32'],
#       dtype='object')
# Accuracy score: 0.9155739274840446
#
# F1 score: 0.6544586274215347
#
# Confusion matrix:
#
#      t/p      0     1
#         0 1138708 48837
#         1 66211 108951
# Sensivity: 0.6220013473241913
# Specificity: 0.9588756636590613
# (0.916, 0.654, 1138708, 48837, 66211, 108951)
